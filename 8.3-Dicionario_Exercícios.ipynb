# %% [markdown]
# # Dicionários
#
# ## Aula 8.3

# %% [markdown]
# ### Q1.
#
# Escreva uma função em Python chamada ```contagem_caracteres``` que recebe uma string como parâmetro e retorna um dicionário onde as chaves são os caracteres presentes na string e os valores são a contagem de cada caractere.

# %%
# Implemente aqui a função contagem_caracteres
def contagem_caracteres(s):
    # Inicializa um dicionário vazio para armazenar a contagem de caracteres
    contagem = {}
    
    # Itera sobre cada caractere na string
    for char in s:
        # Se o caractere já estiver no dicionário, incrementa a contagem
        if char in contagem:
            contagem[char] += 1
        # Caso contrário, adiciona o caractere ao dicionário com contagem 1
        else:
            contagem[char] = 1
    
    return contagem

# Exemplo de uso:
frase = "python programming"
resultado = contagem_caracteres(frase)
print(resultado)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 2, ' ': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1}

# %%
# Exemplo de uso:
frase = "python programming"
resultado = contagem_caracteres(frase)
print(resultado)

# %% [markdown]
# ### Q2.
#
# Baixe o arquivo contendo o roteiro do filme brasileiro "Estômago" e salve em seu computador com o nome "estomago.txt".
#
# https://aplauso.imprensaoficial.com.br/edicoes/12.0.813.502/12.0.813.502.txt
#
# - Escreva um script python que abre o arquivo de texto e cria um dicionário contando a quantidade de vezes que cada palavra aparece no texto.
# - Em seguida ordene o dicionário de forma decrescente pelos valores. Dessa maneira ele irá apresentar as palavras mais frequentes no início.
# - Apresente na tela o dicionário ordenado

# %%
# Implemente aqui sua solução
def contar_palavras(arquivo):
    try:
        with open(arquivo, 'r', encoding='utf-8') as f:
            texto = f.read()

        # Remove pontuações e converte o texto para minúsculas
        texto = texto.lower()
        for char in '.,!?;:"()[]{}\n':
            texto = texto.replace(char, ' ')

        # Divide o texto em palavras
        palavras = texto.split()

        # Cria um dicionário para contar as palavras
        contagem = {}
        for palavra in palavras:
            if palavra in contagem:
                contagem[palavra] += 1
            else:
                contagem[palavra] = 1

        # Ordena o dicionário pelos valores (contagem) de forma decrescente
        contagem_ordenada = dict(sorted(contagem.items(), key=lambda item: item[1], reverse=True))

        return contagem_ordenada
    except FileNotFoundError:
        print(f"Erro: O arquivo '{arquivo}' não foi encontrado.")
        return {}

# Nome do arquivo de texto
arquivo = 'RoteiroFilmeEstomago.txt'  # Certifique-se de que o nome está correto

# Conta as palavras e ordena
resultado = contar_palavras(arquivo)

# Exibe o dicionário ordenado
for palavra, quantidade in resultado.items():
    print(f"{palavra}: {quantidade}")
# Out:
# de: 1274
# e: 960
# o: 910
# a: 750
# nonato: 668
# que: 661
# um: 477
# do: 404
# é: 347
# com: 332
# não: 297
# da: 292
# uma: 288
# no: 243
# na: 235
# em: 235
# se: 227
# para: 222
# –: 211
# os: 186
# giovanni: 157
# mas: 153
# íria: 144
# eu: 132
# bujiú: 123
# as: 121
# por: 120
# cozinha: 109
# tem: 104
# mais: 102
# ele: 101
# zulmiro: 99
# pra: 98
# ao: 97
# como: 96
# seu: 96
# tá: 91
# está: 84
# você: 83
# bem: 80
# vai: 79
# foi: 77
# cena: 75
# aqui: 74
# dos: 72
# faz: 70
# cela: 68
# roteiro: 67
# filme: 67
# isso: 67
# int: 66
# pouco: 65
# até: 63
# tudo: 63
# lá: 62
# mesmo: 60
# muito: 58
# então: 58
# já: 56
# olha: 56
# estômago: 54
# fazer: 52
# dentro: 51
# também: 51
# sobre: 51
# alho: 50
# dia: 48
# era: 48
# coisa: 48
# são: 46
# bom: 46
# dá: 46
# meio: 45
# esse: 45
# me: 45
# só: 45
# 1: 45
# restaurante: 44
# prato: 44
# quando: 42
# esta: 41
# à: 40
# das: 40
# ser: 40
# pode: 40
# ou: 39
# alecrim: 39
# panela: 39
# aí: 38
# depois: 37
# comida: 37
# ...

# %% [markdown]
# ### Q3.
#
# Crie uma função chamada ```mesclar_dicionarios``` que recebe dois dicionários como parâmetros e retorna um novo dicionário contendo a fusão dos dois. Se houver chaves comuns, o maior valor deve prevalecer.

# %%
def mesclar_dicionarios(dic1, dic2):
    # Cria uma cópia do primeiro dicionário para não modificar o original
    resultado = dic1.copy()
    
    # Itera sobre as chaves e valores do segundo dicionário
    for chave, valor in dic2.items():
        # Se a chave já existe no resultado, compara os valores e mantém o maior
        if chave in resultado:
            resultado[chave] = max(resultado[chave], valor)
        else:
            # Se a chave não existe, adiciona ao resultado
            resultado[chave] = valor
    
    return resultado

# Exemplo de uso:
dicionario1 = {'a': 1, 'b': 2, 'c': 3}
dicionario2 = {'b': 4, 'd': 5}

# Chama a função para mesclar os dicionários
resultado = mesclar_dicionarios(dicionario1, dicionario2)

# Exibe o resultado
print(resultado)
# Out:
# {'a': 1, 'b': 4, 'c': 3, 'd': 5}

# %%
# Exemplo de uso:
dicionario1 = {'a': 1, 'b': 2, 'c': 3}
dicionario2 = {'b': 4, 'd': 5}
resultado = mesclar_dicionarios(dicionario1, dicionario2)
print(resultado)
# Saída esperada: {'a': 1, 'b': 4, 'c': 3, 'd': 5}

# %% [markdown]
# ### Q5.
#
# Você está responsável por analisar os resultados de uma votação. Cada voto é representado por um dicionário com o nome do candidato e a quantidade de votos que recebeu em uma determinada sessão eleitoral. Escreva uma função chamada ```resultado_votacao``` que recebe uma lista de dicionários de votos e retorna um dicionário onde as chaves são os nomes dos candidatos, e os valores são tuplas ```(total, percentual)``` com o total de votos recebidos por cada candidato e o percentual em relação à soma total de votos em todos os candidatos.

# %% [markdown]
# ### Q4.
#
# Desenvolva uma função em Python chamada ```filtrar_dicionario``` que recebe um dicionário e uma lista de chaves como parâmetros e retorna um novo dicionário contendo apenas as chaves que estão presentes na lista.

# %%
# Implemente aqui a função filtrar_dicionario

def filtrar_dicionario(dicionario, chaves):
    # Cria um novo dicionário apenas com as chaves presentes na lista
    resultado = {chave: dicionario[chave] for chave in chaves if chave in dicionario}
    return resultado

# Exemplo de uso:
dados = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
chaves_filtradas = ['a', 'c', 'e']

# Chama a função para filtrar o dicionário
resultado = filtrar_dicionario(dados, chaves_filtradas)

# Exibe o resultado
print(resultado)
# Out:
# {'a': 1, 'c': 3, 'e': 5}

# %%
# Exemplo de uso:
dados = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
chaves_filtradas = ['a', 'c', 'e']
resultado = filtrar_dicionario(dados, chaves_filtradas)
print(resultado)
# Saída esperada: {'a': 1, 'c': 3, 'e': 5}

# %%
# Implemente aqui a função resultado_votacao
def resultado_votacao(votos):
    # Dicionário para armazenar o total de votos de cada candidato
    total_votos_por_candidato = {}

    # Calcula o total de votos para cada candidato
    for sessao in votos:
        for candidato, votos_sessao in sessao.items():
            if candidato in total_votos_por_candidato:
                total_votos_por_candidato[candidato] += votos_sessao
            else:
                total_votos_por_candidato[candidato] = votos_sessao

    # Calcula o total geral de votos
    total_geral = sum(total_votos_por_candidato.values())

    # Calcula o percentual de votos para cada candidato
    resultado = {}
    for candidato, total in total_votos_por_candidato.items():
        percentual = (total / total_geral) * 100
        resultado[candidato] = (total, round(percentual, 2))  # Arredonda para 2 casas decimais

    return resultado

# Exemplo de uso:
votos = [
    {'candidato_A': 120, 'candidato_B': 85, 'candidato_C': 90},
    {'candidato_A': 110, 'candidato_B': 95, 'candidato_C': 80},
    {'candidato_A': 130, 'candidato_B': 78, 'candidato_C': 105},
]

resultado = resultado_votacao(votos)
print(resultado)
# Out:
# {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 'candidato_C': (275, 30.8)}

# %%
# Exemplo de uso:
votos = [
    {'candidato_A': 120, 'candidato_B': 85, 'candidato_C': 90},
    {'candidato_A': 110, 'candidato_B': 95, 'candidato_C': 80},
    {'candidato_A': 130, 'candidato_B': 78, 'candidato_C': 105},
]
resultado = resultado_votacao(votos)
print(resultado)  # Saída esperada: {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 
                                ###  'candidato_C': (275, 30.79)}
